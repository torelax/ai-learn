# %%
import torch
from torch import nn

# %% [markdown]
# ### 各种网络的参数等

# %% [markdown]
# #### linear 参数
# $Y = X\times W^T + b$
# $X: batch \times x$,  $W: out \times x$,  $b: batch \times out$,  $Y: batch \times out$

# %%
dense = nn.Linear(6, 3)
params = dense.state_dict()

# %%
params['weight'].shape
# Out:
# torch.Size([3, 6])
